# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SalaryData\SalaryData.csv')

# %%
df.head()
# Out:
#    Employee ID  Age  Education  Gender  Project Involvement  Job Level  \
# 0            1   42          2  Female                    3          2
# 1            2   50          1    Male                    2          2
# 2            3   38          2    Male                    2          1
# 3            4   34          4  Female                    3          1
# 4            5   28          1    Male                    3          1
#
#              Job Role  Salary Over 18 years old  Total Working Years  \
# 0  Business Developer    5204                 Y                    8
# 1            Engineer    5134                 Y                   10
# 2          Technician    2103                 Y                    7
# 3            Engineer    2919                 Y                    8
# 4          Technician    3484                 Y                    6
#
#    Years At Company  Years In Current Role
# 0                 6                      4
# 1                10                      7
# 2                 0                      0
# 3                 8                      7
# 4                 2                      2

# %% [markdown]
# Independent variables are : Age , Gender , Over 18 years old , Job Role ,Project Involvement

# %% [markdown]
# dependent variables are : Job Level , Salary , Years At Company , Years In Current Role

# %% [markdown]
# ### Correlation Matrix to get the relavent features

# %%
corr_matrix = df.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\amgad\AppData\Local\Temp\ipykernel_1852\22954263.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# <style type="text/css">
# #T_64df9_row0_col0, #T_64df9_row1_col1, #T_64df9_row2_col2, #T_64df9_row3_col3, #T_64df9_row4_col4, #T_64df9_row5_col5, #T_64df9_row6_col6, #T_64df9_row7_col7, #T_64df9_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_64df9_row0_col1, #T_64df9_row0_col2, #T_64df9_row0_col4, #T_64df9_row0_col5, #T_64df9_row0_col6, #T_64df9_row0_col8, #T_64df9_row3_col2, #T_64df9_row3_col7, #T_64df9_row4_col0, #T_64df9_row5_col0, #T_64df9_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_64df9_row0_col3, #T_64df9_row5_col3, #T_64df9_row6_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_64df9_row0_col7, #T_64df9_row3_col0, #T_64df9_row3_col5, #T_64df9_row3_col6, #T_64df9_row4_col3, #T_64df9_row8_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_64df9_row1_col0, #T_64df9_row3_col4, #T_64df9_row6_col0, #T_64df9_row7_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_64df9_row1_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_64df9_row1_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_64df9_row1_col4, #T_64df9_row4_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_64df9_row1_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_64df9_row1_col6, #T_64df9_row6_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_64df9_row1_col7 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_64df9_row1_col8, #T_64df9_row2_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_64df9_row2_col0, #T_64df9_row5_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_64df9_row2_col3, #T_64df9_row4_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_64df9_row2_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_64df9_row2_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_64df9_row2_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_64df9_row2_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_64df9_row2_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_64df9_row3_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_64df9_row3_col8, #T_64df9_row8_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_64df9_row4_col5, #T_64df9_row5_col4 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_64df9_row4_col6, #T_64df9_row6_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_64df9_row4_col7, #T_64df9_row7_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_64df9_row4_col8 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_64df9_row5_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_64df9_row5_col6, #T_64df9_row6_col5 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_64df9_row5_col7 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_64df9_row5_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_64df9_row6_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_64df9_row6_col7, #T_64df9_row7_col6 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_64df9_row6_col8, #T_64df9_row8_col6 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_64df9_row7_col1 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_64df9_row7_col2, #T_64df9_row8_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_64df9_row7_col5 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_64df9_row7_col8 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_64df9_row8_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_64df9_row8_col4 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_64df9_row8_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_64df9_row8_col7 {
#   background-color: #f39475;
#   color: #000000;
# }
# </style>
# <table id="T_64df9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64df9_level0_col0" class="col_heading level0 col0" >Employee ID</th>
#       <th id="T_64df9_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_64df9_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_64df9_level0_col3" class="col_heading level0 col3" >Project Involvement</th>
#       <th id="T_64df9_level0_col4" class="col_heading level0 col4" >Job Level</th>
#       <th id="T_64df9_level0_col5" class="col_heading level0 col5" >Salary</th>
#       <th id="T_64df9_level0_col6" class="col_heading level0 col6" >Total Working Years</th>
#       <th id="T_64df9_level0_col7" class="col_heading level0 col7" >Years At Company</th>
#       <th id="T_64df9_level0_col8" class="col_heading level0 col8" >Years In Current Role</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64df9_level0_row0" class="row_heading level0 row0" >Employee ID</th>
#       <td id="T_64df9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_64df9_row0_col1" class="data row0 col1" >-0.011210</td>
#       <td id="T_64df9_row0_col2" class="data row0 col2" >0.041461</td>
#       <td id="T_64df9_row0_col3" class="data row0 col3" >-0.006912</td>
#       <td id="T_64df9_row0_col4" class="data row0 col4" >-0.018156</td>
#       <td id="T_64df9_row0_col5" class="data row0 col5" >-0.018442</td>
#       <td id="T_64df9_row0_col6" class="data row0 col6" >-0.013508</td>
#       <td id="T_64df9_row0_col7" class="data row0 col7" >-0.012154</td>
#       <td id="T_64df9_row0_col8" class="data row0 col8" >-0.009489</td>
#     </tr>
#     <tr>
#       <th id="T_64df9_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_64df9_row1_col0" class="data row1 col0" >-0.011210</td>
#       <td id="T_64df9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_64df9_row1_col2" class="data row1 col2" >0.210471</td>
#       <td id="T_64df9_row1_col3" class="data row1 col3" >0.029040</td>
#       <td id="T_64df9_row1_col4" class="data row1 col4" >0.510511</td>
#       <td id="T_64df9_row1_col5" class="data row1 col5" >0.521929</td>
#       <td id="T_64df9_row1_col6" class="data row1 col6" >0.681912</td>
#       <td id="T_64df9_row1_col7" class="data row1 col7" >0.313049</td>
#       <td id="T_64df9_row1_col8" class="data row1 col8" >0.214163</td>
#     </tr>
#     <tr>
#       <th id="T_64df9_level0_row2" class="row_heading level0 row2" >Education</th>
#       <td id="T_64df9_row2_col0" class="data row2 col0" >0.041461</td>
#       <td id="T_64df9_row2_col1" class="data row2 col1" >0.210471</td>
#       <td id="T_64df9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_64df9_row2_col3" class="data row2 col3" >0.043171</td>
#       <td id="T_64df9_row2_col4" class="data row2 col4" >0.101566</td>
#       <td id="T_64df9_row2_col5" class="data row2 col5" >0.098225</td>
#       <td id="T_64df9_row2_col6" class="data row2 col6" >0.148527</td>
#       <td id="T_64df9_row2_col7" class="data row2 col7" >0.068105</td>
#       <td id="T_64df9_row2_col8" class="data row2 col8" >0.059359</td>
#     </tr>
#     <tr>
#       <th id="T_64df9_level0_row3" class="row_heading level0 row3" >Project Involvement</th>
#       <td id="T_64df9_row3_col0" class="data row3 col0" >-0.006912</td>
#       <td id="T_64df9_row3_col1" class="data row3 col1" >0.029040</td>
#       <td id="T_64df9_row3_col2" class="data row3 col2" >0.043171</td>
#       <td id="T_64df9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_64df9_row3_col4" class="data row3 col4" >-0.012587</td>
#       <td id="T_64df9_row3_col5" class="data row3 col5" >-0.007769</td>
#       <td id="T_64df9_row3_col6" class="data row3 col6" >-0.005574</td>
#       <td id="T_64df9_row3_col7" class="data row3 col7" >-0.020902</td>
#       <td id="T_64df9_row3_col8" class="data row3 col8" >0.009129</td>
#     </tr>
#     <tr>
#       <th id="T_64df9_level0_row4" class="row_heading level0 row4" >Job Level</th>
#       <td id="T_64df9_row4_col0" class="data row4 col0" >-0.018156</td>
#       <td id="T_64df9_row4_col1" class="data row4 col1" >0.510511</td>
#       <td id="T_64df9_row4_col2" class="data row4 col2" >0.101566</td>
#       <td id="T_64df9_row4_col3" class="data row4 col3" >-0.012587</td>
#       <td id="T_64df9_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_64df9

# %% [markdown]
# ### Drop irrelevant features and features with correlation less than +-0.15 with the salary

# %%
X = df.drop(['Employee ID','Salary','Education','Project Involvement','Over 18 years old'],axis = 1)
y = df['Salary']

# %%
plt.figure(figsize=(20,15))

plt.subplot(2,2,1)
plt.scatter(df['Age'], df['Job Level'])
plt.xlabel('Feature Age')
plt.ylabel('Feature Job Level')

plt.subplot(2,2,2)
plt.scatter(df['Age'], df['Salary'])
plt.xlabel('Feature Age')
plt.ylabel('Feature Salary')

plt.subplot(2,2,3)
plt.scatter(df['Age'], df['Years At Company'])
plt.xlabel('Feature Age')
plt.ylabel('Years At Company')
plt.show()

plt.subplot(2,2,4)
plt.scatter(df['Age'], df['Years In Current Role'])
plt.xlabel('Feature Age')
plt.ylabel('Years In Current Role')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [34], line 3
#       1 plt.figure(figsize=(20,15))
# ----> 3 plt.subplot(2,2,0)
#       4 plt.scatter(df['Age'], df['Job Level'])
#       5 plt.xlabel('Feature Age')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py:1252, in subplot(*args, **kwargs)
#    1249 fig = gcf()
#    1251 # First, search for an existing subplot with a matching spec.
# -> 1252 key = SubplotSpec._from_subplot_args(fig, args)
#    1254 for ax in fig.axes:
#    1255     # if we found an Axes at the position sort out if we can re-use it
#    1256     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1257         # if the user passed no kwargs, re-use
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\gridspec.py:612, in SubplotSpec._from_subplot_args(figure, args)
#     610 else:
#     611     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 612         raise ValueError(
#     613             f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     614     i = j = num
#     615 return gs[i-1:j]
#
# ValueError: num must be 1 <= num <= 4, not 0
